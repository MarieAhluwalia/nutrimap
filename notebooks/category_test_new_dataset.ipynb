# %%
import sys
import os

# Add parent folder to Python path
sys.path.append(os.path.abspath(".."))

# %%
from nutrimap_app.data_prep_marie import clean_food_data; clean_food_data()
# Out:
#                                                 food_item  energy_kcal  fat_g  \
# 0                                             Garlic, raw        597.0   0.38
# 6                                      Onions, white, raw         35.0   0.13
# 7                   Apples, red delicious, with skin, raw        258.0   0.21
# 8                      Apples, honeycrisp, with skin, raw         60.0   0.10
# 9                    Apples, granny smith, with skin, raw         59.0   0.14
# ...                                                   ...          ...    ...
# 454224  H.K ANDERSON - peanut butter filled pretzel nu...        467.0  20.00
# 454225               BIRDS EYE - petite whole green beans         35.0   0.00
# 454226                MANCINI - sliced-sweet fried onions         67.0   3.33
# 454227       OBERTO - spicy sweet beef jerky, spicy sweet        286.0   0.00
# 454228                             PENNYSTICKS - pretzels        393.0   1.79
#
#         satfat_g  carbs_g  protein_g  fiber_g  energy_kcal_calculated
# 0           0.00    28.20       6.62      2.7                   142.7
# 6           0.00     7.68       0.89      1.2                    35.4
# 7           0.00    14.80       0.19      2.0                    61.8
# 8           0.00    14.70       0.10      1.7                    60.1
# 9           0.00    14.20       0.27      2.5                    59.1
# ...          ...      ...        ...      ...                     ...
# 454224      3.33    56.67      16.67      3.3                   473.4
# 454225      0.00     7.06       2.35      2.4                    37.6
# 454226      0.00     6.67       0.00      3.3                    56.6
# 454227      0.00    32.14      35.71      3.6                   271.4
# 454228      0.00    82.14      10.71      7.1                   387.5
#
# [405662 rows x 8 columns]

# %%
from nutrimap_app.category_mapping import assign_food_group
df_clean["food_category"] = df_clean.apply(assign_food_group, axis=1)
df_clean.head(50)

# %%
df_clean.sample(100, random_state=42)
