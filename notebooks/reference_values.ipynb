# %% [markdown]
# Reference values

# %%
# Reference values, using EFSA RI
EFSA_RI = {
    "energy_kcal": 666,
    "protein_g": 17,
    "carbs_g": 86,
    "sugar_g": 30
    "fat_g": 23,
    "fiber_g": 10
}
